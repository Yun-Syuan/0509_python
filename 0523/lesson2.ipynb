# %%
for i in range(5):
    print(i)

# %%
for i in range(1,5):
    print(i)

# %%
for i in range(1,10,2):
    print(i)

# %%
i = 0
i += 1
i += 2
i += 3
i += 4
i += 5
i += 6
i += 7
i += 8
i += 9
i += 10
print(i)

# %%
total = 0
for i in range(50,101):
	total += i

print(total)

# %%
score = int(input("請輸入分數："))

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("F")
